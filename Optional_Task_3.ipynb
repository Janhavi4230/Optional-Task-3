# %% [markdown]
# <a href="https://colab.research.google.com/github/Janhavi4230/Optional-Task-3/blob/main/Optional_Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7ae4c7b1-7e32-421d-8f21-053600830666" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ae4c7b1-7e32-421d-8f21-053600830666">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath='/content/diamonds.csv'
df=pd.read_csv(filepath)

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
# Feature and Target

# %%
x=df.drop("price",axis=1)
y=df["price"]

# %%
# One Hot Encoding

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
# Scale training and testing data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Split dataset

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
# Train model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions

# %%
y_pred = model.predict(x_test)

# %%
y_test
# Out:
# 1388      559
# 50052    2201
# 41645    1238
# 42377    1304
# 17244    6901
#          ...
# 44081    1554
# 23713     633
# 31375     761
# 21772    9836
# 4998     3742
# Name: price, Length: 10788, dtype: int64

# %%
y_pred = model.predict(x_test)

print("Model created successfully!")
print("First 5 predicted prices:")
print(y_pred[:5])
# Out:
# Model created successfully!
# First 5 predicted prices:
# [ 508.31603663 3300.12577851 1985.5312597  2125.52304866 9876.87453928]

# %%
# Calculate R² Score

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)

print("R² Score:", r2)
# Out:
# R² Score: 0.9193399796988827

# %%
# Save the trained model

# %%
import joblib

joblib.dump(model, "diamond_price_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!
